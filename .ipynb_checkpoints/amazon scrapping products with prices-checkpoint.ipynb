# %%
# imports

from bs4 import BeautifulSoup as bs
import pandas as pd
import requests

# %%
# product address , this address come dynamically but for simplicity we take static url
url = 'https://www.amazon.in/s?k=asus+laptops'

# %%
req = requests.get(url,headers={"User-Agent": "Requests"})
bsoup = bs(req.content)
p = bsoup.prettify()
print(p)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
res = bsoup.find_all('div',{'class':'s-result-item'})
for item in res:
    cards = item.find_all('div',{'class':'sg-col-inner'})
    for card in cards:
        if card != None:
            print(find_name(card))
            price_row = row.find_all('a',{'class':'a-size-base'})
            for row in price_row:
                if row != None:
                    print(row)
# Out:
# None
# None
# /ASUS-VivoBook-Integrated-Graphics-M409DA-EK484T/dp/B089TQDG5M/ref=sr_1_1?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-1
# None
# /ASUS-VivoBook-Integrated-Graphics-M409DA-EK484T/dp/B089TQDG5M/ref=sr_1_1?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-1
# /ASUS-VivoBook-Integrated-Graphics-M409DA-EK484T/dp/B089TQDG5M/ref=sr_1_1?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-1
# None
# None
# None
# None
# /ZenBook-i5-8265U-14-inch-Graphics-UX431FL-AN088T/dp/B08BL4FBBN/ref=sr_1_2?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-2
# None
# /ZenBook-i5-8265U-14-inch-Graphics-UX431FL-AN088T/dp/B08BL4FBBN/ref=sr_1_2?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-2
# /ZenBook-i5-8265U-14-inch-Graphics-UX431FL-AN088T/dp/B08BL4FBBN/ref=sr_1_2?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-2
# None
# None
# None
# None
# /ASUS-VivoBook-i3-1005G1-Integrated-X409JA-EK011T/dp/B08BV8CBC9/ref=sr_1_3?dchild=1&keywords=asus+laptops&qid=1612252797&sr=8-3
# None
# ...

# %%
def find_name(card):
    h2 = card.h2
    if h2 != None :
            product_name = h2.a.text
            return product_name
